# %%
# follow output from every line 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd 
import numpy as np

# %%
bills_roster = pd.read_csv("data-3/BillsRoster.csv", index_col= None)
dolphins_roster = pd.read_csv("data-3/DolphinsRoster.csv", index_col = None)
pats_roster = pd.read_csv("data-3/PatsRoster.csv", index_col = None)
jets_roster = pd.read_csv("data-3/NYJRoster.csv", index_col = None)

# %%
four_teams = pd.concat([bills_roster,dolphins_roster,pats_roster,jets_roster])

# %%
four_teams_table = four_teams.drop(columns = "No.")
four_teams_table
# Out:
#                      Player  Age Pos   G  GS   Wt College/Univ BirthDate  \
# 0                Josh Allen   26  QB  16  16  237      Wyoming   5/21/96
# 1             Alec Anderson   23   T   0   0  305         UCLA   10/3/99
# 2                 Eli Ankou   28  DT   0   0  325         UCLA    6/8/94
# 3              Matt Barkley   32  QB   0   0  234          USC    9/8/90
# 4             Boogie Basham   25  DE  15   0  281  Wake Forest  12/16/97
# ..                      ...  ...  ..  ..  ..  ...          ...       ...
# 70      Marcell Harris (IR)   28  LB  11   0  215      Florida    6/9/94
# 71         Nate Herbig (IR)   24  OL  11  11  334     Stanford   7/10/98
# 72     Lamarcus Joyner (IR)   32   S  14  14  185  Florida St.  11/27/90
# 73          Jeff Smith (IR)   25  WR  11   0  195  Boston Col.   4/21/97
# 74  Alijah Vera-Tucker (IR)   23  OG   7   7  308          USC   6/17/99
#
#      Yrs    AV                            Drafted (tm/rnd/yr)  \
# ...

# %%
four_teams_table.to_csv("data-3/week4assignment.csv")
